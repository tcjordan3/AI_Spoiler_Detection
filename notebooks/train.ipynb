# %%
# Setup

import torch
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
    print(f"GPU Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.1f} GB")

# %%
# Clone fresh repository

import os

# Remove any existing directory
# !rm -rf /content/AI_Spoiler_Detection

# Clone fresh
print("Cloning repository...")
# %cd /content
# !git clone https://github.com/tcjordan3/AI_Spoiler_Detection.git

# %cd /content/AI_Spoiler_Detection
# !ls -la

# %%
# Installation requirements

# !pip install transformers pandas numpy beautifulsoup4 tqdm

# %%
# Upload data

from google.colab import drive
drive.mount('/content/drive')

# Create models directory in Drive
# !mkdir -p /content/drive/MyDrive/spoiler_models

# Copy CSVs from Drive to Colab workspace
# !mkdir -p /content/AI_Spoiler_Detection/data/processed
# !cp /content/drive/MyDrive/AI_Spoiler_Detection/data/processed/*.csv /content/AI_Spoiler_Detection/data/processed/
# !ls /content/AI_Spoiler_Detection/data/processed

# %%
# Save models to Drive
import os
os.makedirs('/content/drive/MyDrive/spoiler_models', exist_ok=True)

# Symlink so your code saves to Drive
# !ln -s /content/drive/MyDrive/spoiler_models /content/AI_Spoiler_Detection/models

# %%
# Train

# %cd /content/AI_Spoiler_Detection
# !python src/train.py
